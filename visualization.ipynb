# %%
print ('hello miles')
# Out:
# hello miles

# %%
pip install skimpy
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly.express
# Out:
# ...
#      |████████████████████████████████| 56.0 MB 3.3 MB/s eta 0:00:011
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/bin/python3 /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py prepare_metadata_for_build_wheel /var/folders/sn/w009kb0n6zn_x17gcrqvxt2w0000gn/T/tmp1qacrr9z
#          cwd: /private/var/folders/sn/w009kb0n6zn_x17gcrqvxt2w0000gn/T/pip-install-57srew5o/scipy_6f41efb8e8434e958475c0da410278c0
#     Complete output (44 lines):
# ...

# %%
import pandas as pd
import numpy as np 
from skimpy import clean_columns
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('data/cleansurvey.csv')

# %%
df.plot.hist(stacked=False)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(x='interoperability understanding', y='difficulty frequency', ylabel='understanding')
df.plot.scatter(x='interoperability understanding', y='difficulty frequency', c='difficulty frequency', cmap="viridis", s=50)
# Out:
# <Axes: xlabel='interoperability understanding', ylabel='difficulty frequency'>

# %%
df.plot.hist(x='Interoperability Rating', y='difficulty frequency', ylabel='understanding')
df.plot.scatter(x='Interoperability Rating', y='difficulty frequency', c='difficulty frequency', cmap="viridis", s=50)
# Out:
# <Axes: xlabel='Interoperability Rating', ylabel='difficulty frequency'>

# %%
df.boxplot('Interoperability Rating','interoperability understanding' )
# Out:
# <Axes: title={'center': 'Interoperability Rating'}, xlabel='interoperability understanding'>

# %%
pip install tpot mljar-supervised
# Out:
# ...
#      |████████████████████████████████| 87 kB 7.9 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 128 kB 22.1 MB/s eta 0:00:01
# ...
#   Using cached stopit-1.1.2.tar.gz (18 kB)
# ...
#   Using cached scikit-learn-1.3.0.tar.gz (7.5 MB)
#   Installing build dependencies ... /^C
# anceled
# ERROR: Operation cancelled by user
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
